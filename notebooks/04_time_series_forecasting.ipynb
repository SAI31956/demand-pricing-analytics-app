# %%
# %pip install statsmodels
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
# Out:
# Requirement already satisfied: statsmodels in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (2.4.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (1.17.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\sai kumar\appdata\roaming\python\python314\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sai kumar\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv('../data/processed_data/ecommerce_pricing_clean.csv')
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')

ts = df.groupby('date')['units_sold'].sum()

# %%
model = ARIMA(ts, order=(1,1,1))
model_fit = model.fit()

print(model_fit.summary())
# Out:
# c:\Users\Sai Kumar\AppData\Local\Programs\Python\Python314\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Sai Kumar\AppData\Local\Programs\Python\Python314\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Sai Kumar\AppData\Local\Programs\Python\Python314\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             units_sold   No. Observations:                  365
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1300.273
# Date:                Fri, 16 Jan 2026   AIC                           2606.546
# Time:                        13:14:42   BIC                           2618.237
# Sample:                    01-01-2024   HQIC                          2611.193
#                          - 12-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0642      0.056     -1.140      0.254      -0.174       0.046
# ma.L1         -1.0000      3.505     -0.285      0.775      -7.870       5.870
# sigma2        72.9639    254.999      0.286      0.775    -426.826     572.754
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.59
# Prob(Q):                              0.99   Prob(JB):                         0.45
# Heteroskedasticity (H):               0.82   Skew:                             0.06
# Prob(H) (two-sided):                  0.29   Kurtosis:                         2.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
